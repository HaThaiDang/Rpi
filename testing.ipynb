# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('shrimp_detection/best.pt-20240215T143259Z-001/best.pt')  # Load an official Detect model

# %%
# Define path to the image file
source = 'shrimp_detection/test.png'

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# image 1/1 e:\THAIHA\shrimp_monitoring\shrimp_detection\test.png: 384x640 2 shrimps, 243.3ms
# Speed: 16.1ms preprocess, 243.3ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Run inference on 'bus.jpg' with arguments
model.predict(source, save=True, imgsz=320, conf=0.4)
# Out:
# image 1/1 e:\THAIHA\shrimp_monitoring\shrimp_detection\test.png: 192x320 1 shrimp, 159.5ms
# Speed: 0.0ms preprocess, 159.5ms inference, 2.9ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to C:\Users\hadan\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'shrimp'}
#  obb: None
#  orig_img: array([[[ 95,  66,  67],
#          [ 96,  66,  68],
#          [ 96,  66,  68],
#          ...,
#          [ 79,  54,  54],
#          [ 79,  54,  54],
#          [ 79,  54,  54]],
#
#         [[ 95,  67,  68],
#          [ 95,  66,  68],
#          [ 95,  66,  67],
#          ...,
#          [ 78,  55,  53],
#          [ 78,  55,  53],
#          [ 79,  55,  53]],
#
#         [[ 94,  67,  67],
#          [ 93,  65,  66],
#          [ 93,  65,  66],
#          ...,
#          [ 77,  55,  52],
#          [ 77,  55,  52],
# ...

# %%
results = model.predict(source='shrimp_detection/check.jpg',imgsz=640, conf=0.3, save=True, save_txt=True)
# Out:
# image 1/1 e:\THAIHA\shrimp_monitoring\shrimp_detection\check.jpg: 384x640 2 shrimps, 159.7ms
# Speed: 4.1ms preprocess, 159.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\hadan\runs\detect\predict
# 2 labels saved to C:\Users\hadan\runs\detect\predict\labels

# %%
results = model.predict(source='shrimp_detection/vid.mp4',imgsz=640, conf=0.3, save=True, save_txt=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 3 shrimps, 235.4ms
# video 1/1 (2/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 201.3ms
# video 1/1 (3/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 214.5ms
# video 1/1 (4/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 3 shrimps, 165.5ms
# ...

# %%
pip install lapx
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.5 MB 217.9 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/1.5 MB 326.1 kB/s eta 0:00:05
#    --- ------------------------------------ 0.1/1.5 MB 552.2 kB/s eta 0:00:03
#    ------ --------------------------------- 0.2/1.5 MB 860.2 kB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.5 MB 1.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.5 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.1 MB/s eta 0:00:00
# ...

# %%
results = model.track(source="shrimp_detection/vid.mp4", show=True, save=True)  # Tracking with default tracker
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 199.2ms
# video 1/1 (2/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 202.3ms
# video 1/1 (3/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 169.4ms
# video 1/1 (4/305) e:\THAIHA\shrimp_monitoring\shrimp_detection\vid.mp4: 384x640 2 shrimps, 204.4ms
# ...
